# %%
# Load simulation data
from symtrain.data import load_json_files, create_transcript_dataframe

json_list = load_json_files("../data/raw")
df = create_transcript_dataframe(json_list)
df
# Out:
#                                                  name  \
# 0                             Copy OSA - Parity 2.0 1
# 1             Return Request (Bed Frame/Toppers/Misc)
# 2              Startek_Compassion- Gift Donation. BEG
# 3                        Sales U - Closing Conclusion
# 4                      Startek_Telco_Visual_BEG_Demo
# 5   Arise_Carnival DS - Sales Inquiries - Booking ...
# 6   H21 Health insurance coverage question – Step ...
# 7   TRAINEE STARTS HERE: How did you do? View your...
# 8   H21 Health insurance coverage question – Step ...
# 9                         UCSL eApp – State Specifics
# 10  Demo sym - Prescription Request__BEG - Screen ...
# 11                                   OSA - Parity 2.0
# 12       Sales U - Closing Practice 4 - Empathy Close
# 13  Health Insurance (advanced) Adjust existing pa...
# 14       Sales U - Closing Practice 6 - Urgency Close
# 15  FINANCIAL | B1 Zelle Payment issue - extreme S...
# 16                          BN_ORDER_LOST_REPLACE_ADV
# 17  Arise_Disney Resorts Reservations - Booking Mu...
# 18           C2 Car insurance claim - FNOL – ADVANCED
# 19  H21 Health insurance coverage question – (Real...
# 20       Startek_Compassion- Credit Card Payment. BEG
# 21                               United Flight Change
# 22                            SymTrain - Sym Playback
# 23                      Startek_Walmart - Demo - 2025
# 24              Dick's Sporting Goods - Kayak Pick up
# 25  AT&T - Transition to Sales- Assessment for Wor...
# 26                                       OSA - Parity
# 27  Arise_Carnival CS - Mock Call Assessment (Toll...
# 28                              Salesforce Quote Tool
# 29       Startek_Compassion- Credit Card Payment. ADV
# 30           Copy TLE eApp-Final Producer Signature 2
# 31           Learning Style Assessment Simulation_NAV
# 32                  Zinus Knowledge Check 6 Version 2
# 33  H21 Health insurance coverage question – (Real...
# 34                               Raising a Commitment
# 35                                SymTrain - Overview
# 36                       BN_CANCEL_RELEASED_ORDER_ADV
# 37   C2 Car insurance claim - FNOL – Step 1 (Opening)
#
#                                            transcript
# 0   TRAINEE: Thank you for calling Northwestern Mu...
# 1   TRAINEE: Thank you for calling Zinus, this is ...
# 2   SYM: In this simulation, you will assist the c...
# 3   SYM: It’s closing time for this module.\nSYM: ...
# 4   TRAINEE: Thank you for calling Xfinity Mobile,...
# 5   TRAINEE: Carnival Fun Ships, this is [Agent Na...
# 6   SYM: In this simulation, you will learn how to...
# 7   SYM: Congratulations on running your first sym...
# 8   SYM: You have already opened the call and veri...
# 9   SYM: In this sym, we will review how the UCSL ...
# 10  SYM: Now, you'll write the customer's full nam...
# 11  TRAINEE: Thank you for calling Northwestern Mu...
# 12  SYM: Hello! If you are starting this sym, that...
# 13  TRAINEE: [Greet member and offer assistance] \...
# 14  SYM: Hello! If you are starting this sym, that...
# 15  SYM: [Mario wants to know why a Zelle payment ...
# 16  TRAINEE: Thank you for calling Barnes and Nobl...
# 17  TRAINEE: Thank you for calling Walt Disney Wor...
# 18  TRAINEE: Thank you for calling ABC Insurance. ...
# 19  TRAINEE: Thank you for calling ABC Health Insu...
# 20  SYM: In this simulation, you will assist the c...
# 21  SYM: You were about to begin a simulation Plea...
# 22  SYM: Welcome back! Congratulations on completi...
# 23  TRAINEE: Thank you for calling Walmart Custome...
# 24  SYM: You are about to begin a simulation  Plea...
# 25  SYM: Being an AT&T work from home agent is not...
# 26  TRAINEE: Thank you for calling Northwestern Mu...
# 27  TRAINEE: Thank you for calling Carnival, my na...
# 28  SYM: Today we’re turning quoting chaos into qu...
# 29  SYM: In this simulation, you will assist the c...
# 30  SYM: Da da da da.\nSYM: You did it! You have m...
# 31  SYM: In this simulation we will determine the ...
# 32  SYM: Complete the missing information. For mul...
# 33  TRAINEE: Thank you for calling ABC Health Insu...
# 34  SYM: Click on the arrow at the side of Interac...
# 35  SYM: Welcome to SymTrain! I’m Coach Sym and I’...
# 36  TRAINEE: Thank you for calling Barnes and Nobl...
# 37  TRAINEE: Thank you for calling ABC Insurance. ...

# %%
# Generate embeddings for all transcripts
from symtrain.embeddings import embed_dataframe_column

df = embed_dataframe_column(df, "transcript")
# Out:
# Generated 38 embeddings → 'transcript_emb' (dim=768)

# %%
# Similarity search
from symtrain.search import find_similar

# Example: Find simulations related to payment issues
find_similar(
    df,
    "transcript_emb",
    """Hi, I ordered a shirt last week and paid with my American Express card. I need to update the
payment method because there is an issue with that card. Can you help me?""",
)
# Out:
#                                                  name  similarity
# 36                       BN_CANCEL_RELEASED_ORDER_ADV    0.895486
# 37   C2 Car insurance claim - FNOL – Step 1 (Opening)    0.879906
# 23                      Startek_Walmart - Demo - 2025    0.877854
# 16                          BN_ORDER_LOST_REPLACE_ADV    0.877653
# 6   H21 Health insurance coverage question – Step ...    0.877434

# %%
# Approach 1: Transformer-based clustering
from symtrain.clustering import cluster_embeddings, print_cluster_summary

df = cluster_embeddings(df, "transcript_emb", n_clusters=5)
print_cluster_summary(df, "name", "transcript_emb_cluster")
# Out:
# === Cluster 0 ===
#   - Sales U - Closing Conclusion
#   - TRAINEE STARTS HERE: How did you do? View your Playback!
#   - UCSL eApp – State Specifics
#
# === Cluster 1 ===
#   - Startek_Compassion- Gift Donation. BEG
#   - Startek_Telco_Visual_BEG_Demo
#   - Arise_Carnival DS - Sales Inquiries - Booking created ~ BEG
#
# === Cluster 2 ===
#   - H21 Health insurance coverage question – Step 1 (Opening)
#   - H21 Health insurance coverage question – Step 2 (Gather Information)
#   - H21 Health insurance coverage question – (Real human voice)
#
# === Cluster 3 ===
#   - Zinus Knowledge Check 6 Version 2
#
# === Cluster 4 ===
#   - Copy OSA - Parity 2.0 1
#   - Return Request (Bed Frame/Toppers/Misc)
#   - OSA - Parity 2.0

# %%
# Approach 2: LLM-based categorization
from symtrain.llm import categorize_with_ollama

# Apply to dataframe
df["llm_category"] = df["transcript"].apply(categorize_with_ollama)
df[["name", "llm_category"]]
# Out:
#                                                  name         llm_category
# 0                             Copy OSA - Parity 2.0 1     Insurance Claims
# 1             Return Request (Bed Frame/Toppers/Misc)              Returns
# 2              Startek_Compassion- Gift Donation. BEG       Account Issues
# 3                        Sales U - Closing Conclusion             Training
# 4                      Startek_Telco_Visual_BEG_Demo        Account Issues
# 5   Arise_Carnival DS - Sales Inquiries - Booking ...              Booking
# 6   H21 Health insurance coverage question – Step ...     Insurance Claims
# 7   TRAINEE STARTS HERE: How did you do? View your...    Technical Support
# 8   H21 Health insurance coverage question – Step ...     Insurance Claims
# 9                         UCSL eApp – State Specifics       Account Issues
# 10  Demo sym - Prescription Request__BEG - Screen ...  Prescription Refill
# 11                                   OSA - Parity 2.0     Insurance Claims
# 12       Sales U - Closing Practice 4 - Empathy Close             Training
# 13  Health Insurance (advanced) Adjust existing pa...       Payment Issues
# 14       Sales U - Closing Practice 6 - Urgency Close       Sales Training
# 15  FINANCIAL | B1 Zelle Payment issue - extreme S...       Payment Issues
# 16                          BN_ORDER_LOST_REPLACE_ADV         Order Status
# 17  Arise_Disney Resorts Reservations - Booking Mu...          Reservation
# 18           C2 Car insurance claim - FNOL – ADVANCED     Insurance Claims
# 19  H21 Health insurance coverage question – (Real...     Insurance Claims
# 20       Startek_Compassion- Credit Card Payment. BEG       Account Issues
# 21                               United Flight Change       Flight Changes
# 22                            SymTrain - Sym Playback    Technical Support
# 23                      Startek_Walmart - Demo - 2025              Returns
# 24              Dick's Sporting Goods - Kayak Pick up      Order Placement
# 25  AT&T - Transition to Sales- Assessment for Wor...    Technical Support
# 26                                       OSA - Parity     Insurance Claims
# 27  Arise_Carnival CS - Mock Call Assessment (Toll...            Transfers
# 28                              Salesforce Quote Tool               Quotes
# 29       Startek_Compassion- Credit Card Payment. ADV       Payment Issues
# 30           Copy TLE eApp-Final Producer Signature 2  Training Completion
# 31           Learning Style Assessment Simulation_NAV    Technical Support
# 32                  Zinus Knowledge Check 6 Version 2       Account Issues
# 33  H21 Health insurance coverage question – (Real...     Insurance Claims
# 34                               Raising a Commitment       Account Issues
# 35                                SymTrain - Overview    Technical Support
# 36                       BN_CANCEL_RELEASED_ORDER_ADV         Order Status
# 37   C2 Car insurance claim - FNOL – Step 1 (Opening)     Insurance Claims

# %%
# Task 5: Few-shot learning pipeline
import json
from symtrain.llm import generate_steps_with_ollama

# Test inputs
# test_inputs = {
#     "test_1": "Hi, I ordered a shirt last week and paid with my American Express card. I need to update the payment method because there is an issue with that card. Can you help me?",
#     "test_2": "Hi, I need to update the payment method for one of my recent orders. Can you help me with that?",
#     "test_3": "Hi, I am Sam. I was in a car accident this morning and need to file an insurance claim. Can you help me?",
#     "test_4": "Hi, can you help me file a claim?",
#     "test_5": "Hi, I recently ordered a book online. Can you give me an update on the order status?",
#     "test_6": "Hi, I have been waiting for two weeks for the book I ordered. What is going on with it? Can you give me an update?",
# }

test_inputs = {
    "test_1": "Hi, I ordered a shirt last week and paid with my American Express card. I need to update the payment method because there is an issue with that card. Can you help me?"
}

# Run on all test inputs
results = {}
for test_id, query in test_inputs.items():
    print(f"\nProcessing {test_id}...")
    print(f"test_input: {query}")
    results[test_id] = generate_steps_with_ollama(query, df)
    print(json.dumps(results[test_id], indent=2))
# Out:
# Processing test_1...
# test_input: Hi, I ordered a shirt last week and paid with my American Express card. I need to update the payment method because there is an issue with that card. Can you help me?
# {
#   "category": "Payment Issues",
#   "reason": "The customer wants to change the payment method for an existing order due to a problem with the original card.",
#   "steps": [
#     "Greet the customer and confirm their name and contact information.",
#     "Ask for the order number and verify the order details (item, date, amount, original payment method).",
#     "Check the payment status of the order in the system.",
#     "Explain whether the payment can be modified directly (e.g., if the order is still pending) or if the order must be canceled/refunded and a new order placed.",
#     "If the order can be updated, process the new payment method (American Express replacement or another card) and confirm the transaction.",
#     "If a cancellation/refund is required, initiate the cancellation, process the refund to the original card, and guide the customer to place a new order with the updated payment method.",
#     "Confirm the updated payment details or new order number with the customer.",
#     "Provide a reference number, summarize the actions taken, and ask if there is anything else they need assistance with.",
#     "Close the call politely, thanking the customer for their patience."
#   ]
# }
